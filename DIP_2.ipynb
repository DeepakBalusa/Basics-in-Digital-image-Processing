# %%
from PIL import Image

# %%
csk=Image.open("/content/nithish_de_raina___storybitapputm_medium=copy_link____2057198369.jpg")

# %%
csk.show()

# %%
csk_l=csk.convert("L") 
csk_l.show() 
csk_l
# Out:
# <PIL.Image.Image image mode=L size=1080x1350 at 0x7FA73C7C70D0>

# %%
csk_resize=csk.resize((512,512)) 
csk_resize
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FA73C7A5190>

# %%
csk_resize.show()

# %%
csk_rotate=csk.rotate(90)

# %%
csk_rotate

# %%
csk_rotate.show()

# %%
csk_rotate=csk.rotate(-45)

# %%
csk_rotate.size
# Out:
# (1080, 1350)

# %%
csk_rotate.save("new.png")
